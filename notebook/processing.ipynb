# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv("/home/sanjeevpatil/End-to-End Hotel Reservation Prediction/Artifacts/11_02_2025_19_50_14/data_ingestion/feature_store/HotelReservation.csv")

# %%
X = df.drop(columns=['booking_status'])
y = df['booking_status']

# %%
X.drop(columns=['Booking_ID'], inplace=True)

# %%
X.shape
# Out:
# (36275, 17)
